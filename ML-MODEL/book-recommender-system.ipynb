# %%
import numpy as np
import pandas as pd

# %%
books = pd.read_csv('books.csv')
users = pd.read_csv('users.csv')
ratings = pd.read_csv('ratings.csv')
# Out:
# C:\Users\sahil\AppData\Local\Temp\ipykernel_4352\3819754567.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   books = pd.read_csv('books.csv')

# %%
books['Image-URL-M'][1]
# Out:
# 'http://images.amazon.com/images/P/0002005018.01.MZZZZZZZ.jpg'

# %%
users.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
ratings.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
print(books.shape)
print(ratings.shape)
print(users.shape)
# Out:
# (271360, 8)
# (1149780, 3)
# (278858, 3)

# %%
books.isnull().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            2
# Year-Of-Publication    0
# Publisher              2
# Image-URL-S            0
# Image-URL-M            0
# Image-URL-L            3
# dtype: int64

# %%
users.isnull().sum()
# Out:
# User-ID          0
# Location         0
# Age         110762
# dtype: int64

# %%
ratings.isnull().sum()
# Out:
# User-ID        0
# ISBN           0
# Book-Rating    0
# dtype: int64

# %%
books.duplicated().sum()
# Out:
# 0

# %%
ratings.duplicated().sum()
# Out:
# 0

# %%
users.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## Popularity Based Recommender System

# %%
ratings_with_name = ratings.merge(books,on='ISBN')

# %%
num_rating_df = ratings_with_name.groupby('Book-Title').count()['Book-Rating'].reset_index()
num_rating_df.rename(columns={'Book-Rating':'num_ratings'},inplace=True)
num_rating_df
# Out:
#                                               Book-Title  num_ratings
# 0       Earth Prayers From around the World: 365 Pray...           10
# 1       Final Fantasy Anthology: Official Strategy Gu...            4
# 2       Flight of Fancy: American Heiresses (Zebra Ba...            2
# 3       Little Comic Shop of Horrors (Give Yourself G...            4
# 4                                           Mystery Mile            2
# ...                                                  ...          ...
# 68750                                      Ã?Â?lpiraten.            2
# 68751                     Ã?Â?rger mit Produkt X. Roman.            4
# 68752                                Ã?Â?sterlich leben.            1
# 68753                              Ã?Â?stlich der Berge.            3
# 68754                                  Ã?Â?thique en toc            2
#
# [68755 rows x 2 columns]

# %%
avg_rating_df = ratings_with_name.groupby('Book-Title', as_index=False)['Book-Rating'].mean()
avg_rating_df.rename(columns={'Book-Rating': 'avg_rating'}, inplace=True)

print(avg_rating_df)  # Display the dataframe
# Out:
#                                               Book-Title  avg_rating
# 0       Earth Prayers From around the World: 365 Pray...    5.000000
# 1       Final Fantasy Anthology: Official Strategy Gu...    5.000000
# 2       Flight of Fancy: American Heiresses (Zebra Ba...    4.000000
# 3       Little Comic Shop of Horrors (Give Yourself G...    1.250000
# 4                                           Mystery Mile    0.000000
# ...                                                  ...         ...
# 68750                                      Ã?Â?lpiraten.    0.000000
# 68751                     Ã?Â?rger mit Produkt X. Roman.    5.250000
# 68752                                Ã?Â?sterlich leben.    7.000000
# 68753                              Ã?Â?stlich der Berge.    2.666667
# 68754                                  Ã?Â?thique en toc    4.000000
#
# [68755 rows x 2 columns]

# %%
popular_df = num_rating_df.merge(avg_rating_df,on='Book-Title')
popular_df
# Out:
#                                               Book-Title  num_ratings  \
# 0       Earth Prayers From around the World: 365 Pray...           10
# 1       Final Fantasy Anthology: Official Strategy Gu...            4
# 2       Flight of Fancy: American Heiresses (Zebra Ba...            2
# 3       Little Comic Shop of Horrors (Give Yourself G...            4
# 4                                           Mystery Mile            2
# ...                                                  ...          ...
# 68750                                      Ã?Â?lpiraten.            2
# 68751                     Ã?Â?rger mit Produkt X. Roman.            4
# 68752                                Ã?Â?sterlich leben.            1
# 68753                              Ã?Â?stlich der Berge.            3
# 68754                                  Ã?Â?thique en toc            2
#
#        avg_rating
# 0        5.000000
# 1        5.000000
# 2        4.000000
# 3        1.250000
# 4        0.000000
# ...           ...
# 68750    0.000000
# 68751    5.250000
# 68752    7.000000
# 68753    2.666667
# 68754    4.000000
#
# [68755 rows x 3 columns]

# %%
popular_df = popular_df[popular_df['num_ratings']>=250].sort_values('avg_rating',ascending=False).head(50)

# %%
popular_df = popular_df.merge(books,on='Book-Title').drop_duplicates('Book-Title')[['Book-Title','Book-Author','Image-URL-M','num_ratings','avg_rating']]

# %%
popular_df['Image-URL-M'][0]
# Out:
# 'http://images.amazon.com/images/P/043935806X.01.MZZZZZZZ.jpg'

# %% [markdown]
# ## Collaborative Filtering Based Recommender System

# %%
x = ratings_with_name.groupby('User-ID').count()['Book-Rating'] > 200
padhe_likhe_users = x[x].index

# %%
padhe_likhe_users
# Out:
# Index([  8890,  11601,  11676,  16795,  23768,  23902,  26544,  35859,  36606,
#         36836,  52584,  55492,  56399,  60244,  69697,  72992,  73394,  76352,
#         76626,  78783,  87141,  93047,  95359,  98391,  98741, 102967, 110973,
#        115120, 127233, 129358, 135149, 142524, 148744, 153662, 160032, 162639,
#        170229, 171118, 172742, 173632, 175003, 177458, 182085, 182987, 185233,
#        189334, 189835, 190925, 198711, 204864, 212898, 213350, 217740, 226545,
#        227447, 230522, 231210, 232131, 234623, 235105, 238781, 241198, 242824,
#        245963, 261105, 266226, 275970, 278418],
#       dtype='int64', name='User-ID')

# %%
filtered_rating = ratings_with_name[ratings_with_name['User-ID'].isin(padhe_likhe_users)]

# %%
filtered_rating
# Out:
#         User-ID        ISBN  Book-Rating  \
# 5         23768  034545104X            0
# 18        98391  034545104X            9
# 47       227447  034545104X            0
# 65       278418  038550120X            0
# 70        11676  038550120X           10
# ...         ...         ...          ...
# 196714   275970  1880837927            0
# 196715   275970  188717897X            0
# 196716   275970  1888889047            0
# 196717   275970  1931868123            0
# 196718   275970  3411086211           10
#
#                                                Book-Title  \
# 5                                    Flesh Tones: A Novel
# 18                                   Flesh Tones: A Novel
# 47                                   Flesh Tones: A Novel
# 65                                        A Painted House
# 70                                        A Painted House
# ...                                                   ...
# 196714                         The Theology of the Hammer
# 196715  The Ordeal of Integration: Progress and Resent...
# 196716  Pushcart's Complete Rotten Reviews &amp; Rejec...
# 196717  There's a Porcupine in My Outhouse: Misadventu...
# 196718                                         Die Biene.
#
#                           Book-Author Year-Of-Publication  \
# 5                          M. J. Rose                2002
# 18                         M. J. Rose                2002
# 47                         M. J. Rose                2002
# 65                       JOHN GRISHAM                2001
# 70                       JOHN GRISHAM                2001
# ...                               ...                 ...
# 196714                 Millard Fuller                1994
# 196715              Orlando Patterson                1998
# 196716                 Bill Henderson                1998
# 196717                   Mike Tougias                2002
# 196718  Sybil GrÃ?Â¤fin SchÃ?Â¶nfeldt                1993
#
#                                    Publisher  \
# 5                           Ballantine Books
# 18                          Ballantine Books
# 47                          Ballantine Books
# 65                                 Doubleday
# 70                                 Doubleday
# ...                                      ...
# 196714         Smyth &amp; Helwys Publishing
# 196715                Civitas Book Publisher
# 196716                        Pushcart Press
# 196717                    Capital Books (VA)
# 196718  Bibliographisches Institut, Mannheim
#
#                                               Image-URL-S  \
# 5       http://images.amazon.com/images/P/034545104X.0...
# 18      http://images.amazon.com/images/P/034545104X.0...
# 47      http://images.amazon.com/images/P/034545104X.0...
# 65      http://images.amazon.com/images/P/038550120X.0...
# 70      http://images.amazon.com/images/P/038550120X.0...
# ...                                                   ...
# 196714  http://images.amazon.com/images/P/1880837927.0...
# 196715  http://images.amazon.com/images/P/188717897X.0...
# 196716  http://images.amazon.com/images/P/1888889047.0...
# 196717  http://images.amazon.com/images/P/1931868123.0...
# 196718  http://images.amazon.com/images/P/3411086211.0...
#
#                                               Image-URL-M  \
# 5       http://images.amazon.com/images/P/034545104X.0...
# 18      http://images.amazon.com/images/P/034545104X.0...
# 47      http://images.amazon.com/images/P/034545104X.0...
# 65      http://images.amazon.com/images/P/038550120X.0...
# 70      http://images.amazon.com/images/P/038550120X.0...
# ...                                                   ...
# 196714  http://images.amazon.com/images/P/1880837927.0...
# 196715  http://images.amazon.com/images/P/188717897X.0...
# 196716  http://images.amazon.com/images/P/1888889047.0...
# 196717  http://images.amazon.com/images/P/1931868123.0...
# 196718  http://images.amazon.com/images/P/3411086211.0...
#
#                                               Image-URL-L
# 5       http://images.amazon.com/images/P/034545104X.0...
# 18      http://images.amazon.com/images/P/034545104X.0...
# 47      http://images.amazon.com/images/P/034545104X.0...
# 65      http://images.amazon.com/images/P/038550120X.0...
# 70      http://images.amazon.com/images/P/038550120X.0...
# ...                                                   ...
# 196714  http://images.amazon.com/images/P/1880837927.0...
# 196715  http://images.amazon.com/images/P/188717897X.0...
# 196716  http://images.amazon.com/images/P/1888889047.0...
# 196717  http://images.amazon.com/images/P/1931868123.0...
# 196718  http://images.amazon.com/images/P/3411086211.0...
#
# [25199 rows x 10 columns]

# %%
y = filtered_rating.groupby('Book-Title').count()['Book-Rating']>=10
famous_books = y[y].index

# %%
famous_books
# Out:
# Index(['16 Lighthouse Road', '204 Rosewood Lane', '311 Pelican Court',
#        'A 2nd Helping of Chicken Soup for the Soul (Chicken Soup for the Soul Series (Paper))',
#        'A Child Called \It\": One Child's Courage to Survive"',
#        'A Fine Balance', 'A Painted House', 'A Patchwork Planet',
#        'A Tangled Web', 'A Widow for One Year',
#        ...
#        'The Tale of the Body Thief (Vampire Chronicles (Paperback))',
#        'The Web (Alex Delaware Series, No. 10)', 'Thursday'S At Eight',
#        'Time Bomb (Alex Delaware Novels (Paperback))', 'Turtle Moon',
#        'Undead and Unwed (Berkley Sensation)', 'Up Island: A Novel',
#        'Welcome to the World, Baby Girl!',
#        'What Looks Like Crazy On An Ordinary Day', 'White Mountain'],
#       dtype='object', name='Book-Title', length=128)

# %%
final_ratings = filtered_rating[filtered_rating['Book-Title'].isin(famous_books)]

# %%
final_ratings
# Out:
#         User-ID        ISBN  Book-Rating              Book-Title  \
# 65       278418  038550120X            0         A Painted House
# 70        11676  038550120X           10         A Painted House
# 85        23768  038550120X            0         A Painted House
# 128       98741  038550120X            0         A Painted House
# 178      162639  038550120X            0         A Painted House
# ...         ...         ...          ...                     ...
# 146817   177458  039914823X            0          How to Be Good
# 154956   102967  051511992x            0      That Camden Summer
# 169661   148744  1551663163            0                 Montana
# 177299   177458  1570429898            0       The First Counsel
# 189198   232131  1558002669            0  The Kitchen God's Wife
#
#             Book-Author Year-Of-Publication                Publisher  \
# 65         JOHN GRISHAM                2001                Doubleday
# 70         JOHN GRISHAM                2001                Doubleday
# 85         JOHN GRISHAM                2001                Doubleday
# 128        JOHN GRISHAM                2001                Doubleday
# 178        JOHN GRISHAM                2001                Doubleday
# ...                 ...                 ...                      ...
# 146817      Nick Hornby                2001             Putnam Adult
# 154956  Lavyrle Spencer                1997               Jove Books
# 169661  Debbie Macomber                1997               Mira Books
# 177299     Brad Meltzer                2001  Time Warner Audio Major
# 189198          Amy Tan                1991         Audio Literature
#
#                                               Image-URL-S  \
# 65      http://images.amazon.com/images/P/038550120X.0...
# 70      http://images.amazon.com/images/P/038550120X.0...
# 85      http://images.amazon.com/images/P/038550120X.0...
# 128     http://images.amazon.com/images/P/038550120X.0...
# 178     http://images.amazon.com/images/P/038550120X.0...
# ...                                                   ...
# 146817  http://images.amazon.com/images/P/039914823X.0...
# 154956  http://images.amazon.com/images/P/051511992X.0...
# 169661  http://images.amazon.com/images/P/1551663163.0...
# 177299  http://images.amazon.com/images/P/1570429898.0...
# 189198  http://images.amazon.com/images/P/1558002669.0...
#
#                                               Image-URL-M  \
# 65      http://images.amazon.com/images/P/038550120X.0...
# 70      http://images.amazon.com/images/P/038550120X.0...
# 85      http://images.amazon.com/images/P/038550120X.0...
# 128     http://images.amazon.com/images/P/038550120X.0...
# 178     http://images.amazon.com/images/P/038550120X.0...
# ...                                                   ...
# 146817  http://images.amazon.com/images/P/039914823X.0...
# 154956  http://images.amazon.com/images/P/051511992X.0...
# 169661  http://images.amazon.com/images/P/1551663163.0...
# 177299  http://images.amazon.com/images/P/1570429898.0...
# 189198  http://images.amazon.com/images/P/1558002669.0...
#
#                                               Image-URL-L
# 65      http://images.amazon.com/images/P/038550120X.0...
# 70      http://images.amazon.com/images/P/038550120X.0...
# 85      http://images.amazon.com/images/P/038550120X.0...
# 128     http://images.amazon.com/images/P/038550120X.0...
# 178     http://images.amazon.com/images/P/038550120X.0...
# ...                                                   ...
# 146817  http://images.amazon.com/images/P/039914823X.0...
# 154956  http://images.amazon.com/images/P/051511992X.0...
# 169661  http://images.amazon.com/images/P/1551663163.0...
# 177299  http://images.amazon.com/images/P/1570429898.0...
# 189198  http://images.amazon.com/images/P/1558002669.0...
#
# [1838 rows x 10 columns]

# %%
pt = final_ratings.pivot_table(index='Book-Title',columns='User-ID',values='Book-Rating')

# %%
pt.fillna(0,inplace=True)

# %%
pt
# Out:
# User-ID                                             11601   11676   16795   \
# Book-Title
# 16 Lighthouse Road                                     0.0     0.0     0.0
# 204 Rosewood Lane                                      0.0     0.0     0.0
# 311 Pelican Court                                      0.0     0.0     0.0
# A 2nd Helping of Chicken Soup for the Soul (Chi...     0.0     0.0     0.0
# A Child Called \It\": One Child's Courage to Su...     0.0     0.0    10.0
# ...                                                    ...     ...     ...
# Undead and Unwed (Berkley Sensation)                   0.0     0.0     0.0
# Up Island: A Novel                                     0.0     9.0     0.0
# Welcome to the World, Baby Girl!                       0.0     0.0     0.0
# What Looks Like Crazy On An Ordinary Day               0.0    10.0     0.0
# White Mountain                                         0.0     0.0     5.0
#
# User-ID                                             23768   23902   26544   \
# Book-Title
# 16 Lighthouse Road                                     0.0     0.0     0.0
# 204 Rosewood Lane                                      0.0     0.0     0.0
# 311 Pelican Court                                      0.0     0.0     8.0
# A 2nd Helping of Chicken Soup for the Soul (Chi...     0.0     0.0     0.0
# A Child Called \It\": One Child's Courage to Su...     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Undead and Unwed (Berkley Sensation)                   0.0     0.0     0.0
# Up Island: A Novel                                     0.0     0.0     0.0
# Welcome to the World, Baby Girl!                       0.0     0.0     0.0
# What Looks Like Crazy On An Ordinary Day               0.0     0.0     0.0
# White Mountain                                         0.0     0.0     0.0
#
# User-ID                                             35859   36606   36836   \
# Book-Title
# 16 Lighthouse Road                                     0.0     0.0     0.0
# 204 Rosewood Lane                                      0.0     0.0     0.0
# 311 Pelican Court                                      0.0     0.0     0.0
# A 2nd Helping of Chicken Soup for the Soul (Chi...     0.0     0.0     0.0
# A Child Called \It\": One Child's Courage to Su...     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Undead and Unwed (Berkley Sensation)                   0.0     0.0     0.0
# Up Island: A Novel                                     0.0     0.0     0.0
# Welcome to the World, Baby Girl!                       0.0     0.0     0.0
# What Looks Like Crazy On An Ordinary Day               8.0     0.0     0.0
# White Mountain                                         0.0     0.0     0.0
#
# User-ID                                             52584   ...  232131  \
# Book-Title                                                  ...
# 16 Lighthouse Road                                     0.0  ...     0.0
# 204 Rosewood Lane                                      0.0  ...     0.0
# 311 Pelican Court                                      0.0  ...     0.0
# A 2nd Helping of Chicken Soup for the Soul (Chi...     0.0  ...     0.0
# A Child Called \It\": One Child's Courage to Su...     0.0  ...     0.0
# ...                                                    ...  ...     ...
# Undead and Unwed (Berkley Sensation)                   0.0  ...     0.0
# Up Island: A Novel                                     0.0  ...     0.0
# Welcome to the World, Baby Girl!                       0.0  ...     0.0
# What Looks Like Crazy On An Ordinary Day               9.0  ...     0.0
# White Mountain                                         0.0  ...     0.0
#
# User-ID                                             234623  235105  238781  \
# Book-Title
# 16 Lighthouse Road                                     0.0     0.0     0.0
# 204 Rosewood Lane                                      0.0     0.0     0.0
# 311 Pelican Court                                      0.0     0.0     0.0
# A 2nd Helping of Chicken Soup for the Soul (Chi...     0.0     0.0     0.0
# A Child Called \It\": One Child's Courage to Su...     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Undead and Unwed (Berkley Sensation)                   0.0     0.0     0.0
# Up Island: A Novel                                     0.0     0.0     0.0
# Welcome to the World, Baby Girl!                       0.0     0.0     0.0
# What Looks Like Crazy On An Ordinary Day               0.0     0.0     0.0
# White Mountain                                         0.0     0.0     0.0
#
# User-ID                                             242824  245963  261105  \
# Book-Title
# 16 Lighthouse Road                                     0.0     0.0     0.0
# 204 Rosewood Lane                                      0.0     0.0     0.0
# 311 Pelican Court                                      0.0     0.0     0.0
# A 2nd Helping of Chicken Soup for the Soul (Chi...     0.0     0.0     0.0
# A Child Called \It\": One Child's Courage to Su...     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Undead and Unwed (Berkley Sensation)                   0.0     0.0     0.0
# Up Island: A Novel                                     0.0     0.0     0.0
# Welcome to the World, Baby Girl!                       0.0     0.0     0.0
# What Looks Like Crazy On An Ordinary Day               0.0     0.0     0.0
# White Mountain                                         0.0     0.0     0.0
#
# User-ID                                             266226  275970  278418
# Book-Title
# 16 Lighthouse Road                                     0.0     0.0     0.0
# 204 Rosewood Lane                                      0.0     0.0     0.0
# 311 Pelican Court                                      0.0     0.0     0.0
# A 2nd Helping of Chicken Soup for the Soul (Chi...     0.0     0.0     0.0
# A Child Called \It\": One Child's Courage to Su...     0.0     0.0     0.0
# ...                                                    ...     ...     ...
# Undead and Unwed (Berkley Sensation)                   0.0     0.0     0.0
# Up Island: A Novel                                     0.0     0.0     0.0
# Welcome to the World, Baby Girl!                       0.0     0.0     0.0
# What Looks Like Crazy On An Ordinary Day               0.0     0.0     0.0
# White Mountain                                         0.0     0.0     0.0
#
# [128 rows x 63 columns]

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity_scores = cosine_similarity(pt)

# %%
similarity_scores.shape
# Out:
# (706, 706)

# %%
def recommend(book_name):
    # index fetch
    index = np.where(pt.index==book_name)[0][0]
    similar_items = sorted(list(enumerate(similarity_scores[index])),key=lambda x:x[1],reverse=True)[1:5]
    
    data = []
    for i in similar_items:
        item = []
        temp_df = books[books['Book-Title'] == pt.index[i[0]]]
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Title'].values))
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Book-Author'].values))
        item.extend(list(temp_df.drop_duplicates('Book-Title')['Image-URL-M'].values))
        
        data.append(item)
    
    return data

# %%
recommend("Clara Callan")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[129], line 1
# ----> 1 recommend("Clara Callan")
#
# Cell In[111], line 3, in recommend(book_name)
#       1 def recommend(book_name):
#       2     # index fetch
# ----> 3     index = np.where(pt.index==book_name)[0][0]
#       4     similar_items = sorted(list(enumerate(similarity_scores[index])),key=lambda x:x[1],reverse=True)[1:5]
#       6     data = []
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
pt.index[0]
# Out:
# '16 Lighthouse Road'

# %%
import pickle
pickle.dump(popular_df,open('popular.pkl','wb'))

# %%
books.drop_duplicates('Book-Title')
# Out:
#               ISBN                                         Book-Title  \
# 0        195153448                                Classical Mythology
# 1          2005018                                       Clara Callan
# 2         60973129                               Decision in Normandy
# 3        374157065  Flu: The Story of the Great Influenza Pandemic...
# 4        393045218                             The Mummies of Urumchi
# ...            ...                                                ...
# 271354   449906736      Flashpoints: Promise and Peril in a New World
# 271356   525447644                            From One to One Hundred
# 271357  006008667X  Lily Dale : The True Story of the Town that Ta...
# 271358   192126040                        Republic (World's Classics)
# 271359   767409752  A Guided Tour of Rene Descartes' Meditations o...
#
#                  Book-Author Year-Of-Publication  \
# 0         Mark P. O. Morford                2002
# 1       Richard Bruce Wright                2001
# 2               Carlo D'Este                1991
# 3           Gina Bari Kolata                1999
# 4            E. J. W. Barber                1999
# ...                      ...                 ...
# 271354          Robin Wright                1993
# 271356            Teri Sloat                1991
# 271357      Christine Wicker                2004
# 271358                 Plato                1996
# 271359   Christopher  Biffle                2000
#
#                                                Publisher  \
# 0                                Oxford University Press
# 1                                  HarperFlamingo Canada
# 2                                        HarperPerennial
# 3                                   Farrar Straus Giroux
# 4                             W. W. Norton &amp; Company
# ...                                                  ...
# 271354                                  Ballantine Books
# 271356                                      Dutton Books
# 271357                                HarperSanFrancisco
# 271358                           Oxford University Press
# 271359  McGraw-Hill Humanities/Social Sciences/Languages
#
#                                               Image-URL-S  \
# 0       http://images.amazon.com/images/P/0195153448.0...
# 1       http://images.amazon.com/images/P/0002005018.0...
# 2       http://images.amazon.com/images/P/0060973129.0...
# 3       http://images.amazon.com/images/P/0374157065.0...
# 4       http://images.amazon.com/images/P/0393045218.0...
# ...                                                   ...
# 271354  http://images.amazon.com/images/P/0449906736.0...
# 271356  http://images.amazon.com/images/P/0525447644.0...
# 271357  http://images.amazon.com/images/P/006008667X.0...
# 271358  http://images.amazon.com/images/P/0192126040.0...
# 271359  http://images.amazon.com/images/P/0767409752.0...
#
#                                               Image-URL-M  \
# 0       http://images.amazon.com/images/P/0195153448.0...
# 1       http://images.amazon.com/images/P/0002005018.0...
# 2       http://images.amazon.com/images/P/0060973129.0...
# 3       http://images.amazon.com/images/P/0374157065.0...
# 4       http://images.amazon.com/images/P/0393045218.0...
# ...                                                   ...
# 271354  http://images.amazon.com/images/P/0449906736.0...
# 271356  http://images.amazon.com/images/P/0525447644.0...
# 271357  http://images.amazon.com/images/P/006008667X.0...
# 271358  http://images.amazon.com/images/P/0192126040.0...
# 271359  http://images.amazon.com/images/P/0767409752.0...
#
#                                               Image-URL-L
# 0       http://images.amazon.com/images/P/0195153448.0...
# 1       http://images.amazon.com/images/P/0002005018.0...
# 2       http://images.amazon.com/images/P/0060973129.0...
# 3       http://images.amazon.com/images/P/0374157065.0...
# 4       http://images.amazon.com/images/P/0393045218.0...
# ...                                                   ...
# 271354  http://images.amazon.com/images/P/0449906736.0...
# 271356  http://images.amazon.com/images/P/0525447644.0...
# 271357  http://images.amazon.com/images/P/006008667X.0...
# 271358  http://images.amazon.com/images/P/0192126040.0...
# 271359  http://images.amazon.com/images/P/0767409752.0...
#
# [242131 rows x 8 columns]

# %%
pickle.dump(pt,open('pt.pkl','wb'))
pickle.dump(books,open('books.pkl','wb'))
pickle.dump(similarity_scores,open('similarity_scores.pkl','wb'))
